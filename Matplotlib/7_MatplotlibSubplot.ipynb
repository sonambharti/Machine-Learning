# %% [markdown]
# ## **Subplot in Matplotlib**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.style.use('dark_background')

# %%
study_hours = [2,3,4,4, 5, 6, 7, 7, 8, 9, 9, 10, 11, 11, 12]
marks = [6, 10, 15, 20, 34, 44, 55, 60, 55, 67, 70, 80, 90, 99, 100]

# %%
plt.scatter(study_hours, marks)
plt.show()

# %%
plt.plot(study_hours, marks, 'r--')
plt.show()

# %%
plt.hist(marks)
# Out:
# (array([3., 1., 1., 0., 1., 3., 2., 1., 1., 2.]),
#  array([  6. ,  15.4,  24.8,  34.2,  43.6,  53. ,  62.4,  71.8,  81.2,
#          90.6, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize = (6,6))
plt.plot(study_hours, marks, 'r-')
plt.plot(study_hours, marks, 'bo')

# %%
plt.figure(figsize = (8,8))

plt.subplot(2,2, 1)
plt.scatter(study_hours, marks)

plt.subplot(2,2, 2)
plt.plot(study_hours, marks, 'r--')

plt.subplot(2,2, 3)
plt.hist(marks)

plt.subplot(2,2, 4)
plt.plot(study_hours, marks, 'r-')
plt.plot(study_hours, marks, 'bo')

# Saving the plot in desired location
# plt.savefig('./content/subplot.jpeg', quality = 100, facecolor = 'k')
plt.savefig('./content/subplot.png', facecolor = 'k')

plt.show()
